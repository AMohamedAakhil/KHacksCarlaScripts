# %%
from generate_traffic import GenerateTraffic

traffic1 = GenerateTraffic(number_of_vehicles=1)
tr = traffic1.start_traffic()
# Out:
# ERROR: Spawn failed because of collision at spawn position
# spawned 1 vehicles and 9 walkers, press Ctrl+C to exit.
# {'Vehicle Acceleration': 9.800000190734863,
#  'Vehicle Brake': 0.0,
#  'Vehicle Gear': 0,
#  'Vehicle Hand Brake': False,
#  'Vehicle Manual Gear Shift': False,
#  'Vehicle Speed': 2.450000286102295,
#  'Vehicle Steer': -0.00043982735951431096,
#  'Vehicle Throttle': 0.8500000238418579,
#  'available': <carla.libcarla.VehiclePhysicsControl object at 0x000001FEBF4B3260>,
#  'something': 3.5}
# {'Vehicle Acceleration': 9.7999906539917,
#  'Vehicle Brake': 0.0,
#  'Vehicle Gear': 0,
#  'Vehicle Hand Brake': False,
#  'Vehicle Manual Gear Shift': False,
#  'Vehicle Speed': 2.93999981880188,
#  'Vehicle Steer': -0.00043982735951431096,
#  'Vehicle Throttle': 0.8500000238418579,
#  'available': <carla.libcarla.VehiclePhysicsControl object at 0x000001FEBF4B3370>,
#  'something': 3.5}
# {'Vehicle Acceleration': 8.89793872833252,
#  'Vehicle Brake': 0.0,
# ...

# %%
tr
